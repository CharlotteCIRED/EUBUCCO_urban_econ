# %% [markdown]
# # Demo: PostGIS database access via Python

# %%
# !pip install sshtunnel psycopg2 geopandas
# Out:
# Requirement already satisfied: sshtunnel in c:\users\charl\anaconda3\envs\geo_env\lib\site-packages (0.4.0)
# Requirement already satisfied: psycopg2 in c:\users\charl\anaconda3\envs\geo_env\lib\site-packages (2.9.5)
# Requirement already satisfied: geopandas in c:\users\charl\anaconda3\envs\geo_env\lib\site-packages (0.9.0)
# Requirement already satisfied: paramiko>=2.7.2 in c:\users\charl\anaconda3\envs\geo_env\lib\site-packages (from sshtunnel) (2.11.0)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\charl\anaconda3\envs\geo_env\lib\site-packages (from geopandas) (1.5.0)
# Requirement already satisfied: pyproj>=2.2.0 in c:\users\charl\anaconda3\envs\geo_env\lib\site-packages (from geopandas) (3.3.1)
# Requirement already satisfied: shapely>=1.6 in c:\users\charl\anaconda3\envs\geo_env\lib\site-packages (from geopandas) (1.7.1)
# Requirement already satisfied: fiona>=1.8 in c:\users\charl\anaconda3\envs\geo_env\lib\site-packages (from geopandas) (1.8.20)
# Requirement already satisfied: attrs>=17 in c:\users\charl\anaconda3\envs\geo_env\lib\site-packages (from fiona>=1.8->geopandas) (22.1.0)
# Requirement already satisfied: certifi in c:\users\charl\anaconda3\envs\geo_env\lib\site-packages (from fiona>=1.8->geopandas) (2022.12.7)
# Requirement already satisfied: click>=4.0 in c:\users\charl\anaconda3\envs\geo_env\lib\site-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: cligj>=0.5 in c:\users\charl\anaconda3\envs\geo_env\lib\site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\charl\anaconda3\envs\geo_env\lib\site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: six>=1.7 in c:\users\charl\anaconda3\envs\geo_env\lib\site-packages (from fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: munch in c:\users\charl\anaconda3\envs\geo_env\lib\site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: setuptools in c:\users\charl\anaconda3\envs\geo_env\lib\site-packages (from fiona>=1.8->geopandas) (65.4.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\charl\anaconda3\envs\geo_env\lib\site-packages (from pandas>=0.24.0->geopandas) (2022.4)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\charl\anaconda3\envs\geo_env\lib\site-packages (from pandas>=0.24.0->geopandas) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\charl\anaconda3\envs\geo_env\lib\site-packages (from pandas>=0.24.0->geopandas) (2.8.2)
# Requirement already satisfied: pynacl>=1.0.1 in c:\users\charl\anaconda3\envs\geo_env\lib\site-packages (from paramiko>=2.7.2->sshtunnel) (1.5.0)
# Requirement already satisfied: bcrypt>=3.1.3 in c:\users\charl\anaconda3\envs\geo_env\lib\site-packages (from paramiko>=2.7.2->sshtunnel) (3.2.2)
# Requirement already satisfied: cryptography>=2.5 in c:\users\charl\anaconda3\envs\geo_env\lib\site-packages (from paramiko>=2.7.2->sshtunnel) (38.0.1)
# Requirement already satisfied: cffi>=1.1 in c:\users\charl\anaconda3\envs\geo_env\lib\site-packages (from bcrypt>=3.1.3->paramiko>=2.7.2->sshtunnel) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\charl\anaconda3\envs\geo_env\lib\site-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko>=2.7.2->sshtunnel) (2.21)

# %% [markdown]
# ## Simple example: Connect to and query database

# %%
import psycopg2
import geopandas as gpd
from sshtunnel import SSHTunnelForwarder

import paramiko
import io
with open('C:/Users/charl/OneDrive/Bureau/PrivateKey3', 'r') as f:
    key = f.read()
    pkey = paramiko.RSAKey.from_private_key(io.StringIO(key))

with SSHTunnelForwarder(('194.163.151.34', 22), ssh_username='flo', remote_bind_address=('172.30.0.4', 5432), ssh_pkey= pkey) as server:
    
    server.start()
    print('Server connected.')

    params = {
        'database': 'eubucco',
        'user': 'NvWkXLveTsmzpuuhXdewHwavJFSsSoVa',
        'password': 'sUur5w7PHUufrRqWvcilJ5Gvxk5TbdAu3cLv9gWXWqd6P1GTTqKqZGgexwtpB6eQ',
        'host': 'localhost',
        'port': server.local_bind_port,
        'connect_timeout': 10,
        }

    conn = psycopg2.connect(**params)
    conn.set_session(readonly=True)
    curs = conn.cursor()
    print('Database connected.')

    sql = 'SELECT * FROM data_country;'
    data = gpd.GeoDataFrame.from_postgis(
        sql=sql,
        con=conn,
        geom_col='geometry', 
        index_col='id', 
        )
    print('Data retrieved.')

data
# Out:
# Server connected.
# Database connected.
# Data retrieved.
#                      name                                           geometry  \
# id
# 30    Italy Other-license                                               None
# 2                 Belgium  MULTIPOLYGON (((3859958.019 3160527.233, 38601...
# 3                Bulgaria  MULTIPOLYGON (((5766401.396 2319455.017, 57664...
# 4                 Croatia  MULTIPOLYGON (((4838760.330 2164354.241, 48387...
# 5                  Cyprus  MULTIPOLYGON (((6350643.684 1612948.279, 63506...
# 6                 Czechia  POLYGON ((4662370.809 2843424.355, 4662176.980...
# 9                 Finland  MULTIPOLYGON (((5021622.613 4131171.471, 50216...
# 10                 France  MULTIPOLYGON (((4258616.576 2027881.387, 42586...
# 8                 Estonia  MULTIPOLYGON (((5106412.320 3926401.969, 51064...
# 12                 Greece  MULTIPOLYGON (((5613096.622 1431753.914, 56131...
# 13                Hungary  POLYGON ((5128017.523 2616895.452, 5127957.132...
# 14                Ireland  MULTIPOLYGON (((2929712.486 3415879.475, 29297...
# 15                  Italy  MULTIPOLYGON (((4560620.502 1386032.453, 45605...
# 16                 Latvia  POLYGON ((5315054.383 3759892.709, 5314983.794...
# 17              Lithuania  MULTIPOLYGON (((5020596.593 3642047.672, 50205...
# 19                  Malta  MULTIPOLYGON (((4723420.838 1425948.536, 47234...
# 20            Netherlands  MULTIPOLYGON (((3887714.160 3142199.157, 38878...
# 1                 Austria  MULTIPOLYGON (((4355226.926 2715896.284, 43552...
# 18             Luxembourg  POLYGON ((4057828.255 2933938.706, 4057503.059...
# 22               Portugal  MULTIPOLYGON (((1813379.435 1205642.743, 18133...
# 24               Slovakia  POLYGON ((4847625.307 2796914.196, 4848018.345...
# 25               Slovenia  MULTIPOLYGON (((4602394.199 2493761.241, 46023...
# 26                  Spain  MULTIPOLYGON (((1557019.828 1026751.076, 15569...
# 27                 Sweden  MULTIPOLYGON (((4507091.395 3599243.446, 45070...
# 28            Switzerland  MULTIPOLYGON (((4338457.467 2610995.479, 43384...
# 29  Czechia Other-license                                               None
# 7                 Denmark  MULTIPOLYGON (((4418712.953 3503178.087, 44187...
# 11                Germany  MULTIPOLYGON (((4223953.590 2731509.519, 42239...
# 21                 Poland  MULTIPOLYGON (((4660241.940 3095541.592, 46602...
# 23                Romania  MULTIPOLYGON (((5853010.959 2615986.575, 58530...
#
#                                           convex_hull  \
# id
# 30                                               None
# 2   0103000020DB0B0000010000001D000000DBA80FDCFE76...
# 3   0103000020DB0B00000100000025000000AC6FC021569C...
# 4   0103000020DB0B000001000000190000002940B0D19673...
# 5   0103000020DB0B00000100000029000000B7E56A7E8062...
# 6   0103000020DB0B000001000000230000006E2E4722E8B2...
# 9   0103000020DB0B0000010000002B0000009E64B14613ED...
# 10  0103000020DB0B0000010000002A00000037E0F3CAFE3E...
# 8   0103000020DB0B0000010000003A0000002150E5DC4C32...
# 12  0103000020DB0B0000010000002E00000089C84EC6A96F...
# 13  0103000020DB0B00000100000021000000175EC3AD29D0...
# 14  0103000020DB0B0000010000001E000000A56087A216E9...
# 15  0103000020DB0B0000010000002C000000C945547ADC64...
# 16  0103000020DB0B000001000000360000000D3E7E4A421A...
# 17  0103000020DB0B0000010000001A00000004B231CBEEEB...
# 19  0103000020DB0B0000010000001D00000000F2B355A104...
# 20  0103000020DB0B000001000000220000003B29A53821D5...
# 1   0103000020DB0B0000010000001D0000000DD88A6365D2...
# 18  0103000020DB0B0000010000001D0000006706662D1CC7...
# 22  0103000020DB0B0000010000002400000040B0C781D1B6...
# 24  0103000020DB0B000001000000270000001AC354A2B9B4...
# 25  0103000020DB0B0000010000001E000000ABD860035BA4...
# 26  0103000020DB0B0000010000003300000082682B04C847...
# 27  0103000020DB0B0000010000003400000019D76FA0C54B...
# 28  0103000020DB0B00000100000027000000115110579E30...
# 29                                               None
# 7   0103000020DB0B0000010000003A0000004E156F3E1EF8...
# 11  0103000020DB0B00000100000035000000E4E24781EA88...
# 28  34d7372f-7c82-40d1-9273-5b8d57ce1524  5630476f-a3ac-4577-b58e-ef17dd85d9b4
# 29  b42d2f22-ce73-4fc6-ad11-34d266854a57  edd16df2-b3bc-4dc5-8b26-c4b6dabdb35f
# 7   b99bf94f-38cf-4775-a934-eec3217d18de  e4768ad8-c40a-47bc-baaa-3f9bcc811576
# 11  427c8e60-784e-4ab0-850c-0754699d6756  c8e528fe-f2db-46f5-b2fc-2a2eae0bea42
# 21  16257cd1-e07d-4034-bb15-19a6106fe8e4  6fa17b52-c385-4be1-bd10-a1f797aa5b36
# 23  4f21cb65-4f9c-4140-92e3-c215a0bd15dd  c05b8c0d-b3ae-4d1a-a4fd-932f759792db

# %% [markdown]
# ## Spatial query example: Sending multiple, spatial PostGIS queries

# %%
import psycopg2
from sshtunnel import SSHTunnelForwarder
import geopandas as gpd
import pandas as pd
from contextlib import contextmanager

@contextmanager
def db_tunnel():
    with SSHTunnelForwarder(('194.163.151.34', 22), ssh_username='flo', remote_bind_address=('172.30.0.4', 5432)) as server:
        
        server.start()

        params = {
            'database': 'eubucco',
            'user': 'NvWkXLveTsmzpuuhXdewHwavJFSsSoVa',
            'password': 'sUur5w7PHUufrRqWvcilJ5Gvxk5TbdAu3cLv9gWXWqd6P1GTTqKqZGgexwtpB6eQ',
            'host': 'localhost',
            'port': server.local_bind_port,
            'connect_timeout': 10,
            }

        conn = psycopg2.connect(**params)
        conn.set_session(readonly=True)
        
        yield conn


with db_tunnel() as conn:
    results = []
    boundaries = [
        # Paris, 11e Arrondissement
        'POLYGON ((3762754.4419298171997070 2890991.8044788637198508, 3764095.9635624778456986 2888187.3515811231918633, 3761960.7702519670128822 2888983.4717874415218830, 3761945.1074829874560237 2889266.3062656684778631, 3761744.4274468249641359 2890595.5182541240938008, 3762754.4419298171997070 2890991.8044788637198508))',
        # Vichy
        #'POLYGON ((3812062.8628411777317524 2581341.6049629254266620, 3811694.3412095555104315 2581981.0313450326211751, 3812127.4740968858823180 2582555.1165699004195631, 3812626.5119165452197194 2581535.7130569545552135, 3813359.5603073895908892 2581590.2022620658390224, 3813347.0566178392618895 2580818.7682339800521731, 3814345.0114732668735087 2578388.9866586597636342, 3814389.6237756260670722 2577626.1422555106692016, 3813747.5744092036038637 2577943.7211474208161235, 3812019.8191846804693341 2579188.5741550792008638, 3812062.8628411777317524 2581341.6049629254266620))',
    ]
    
    for boundary in boundaries:
        sql = f"""
            select bu.id, bu.id_source, bc.name as country, br.name as region, b.name as city, bu.height, bu.age, bu.type, bu.type_source, bu.geometry
                from data_building as bu
                    RIGHT OUTER JOIN data_country bc on bu.country_id = bc.id
                    RIGHT OUTER JOIN data_region br on br.id = bu.region_id
                    RIGHT OUTER JOIN data_city b on b.id = bu.city_id
                WHERE ST_Within( bu.geometry, 'SRID=3035;{boundary}');
        """

        result = gpd.GeoDataFrame.from_postgis(
            sql=sql,
            con=conn,
            geom_col='geometry', 
            index_col='id', 
            )

        #results.append(result)
        result.to_csv("Paris.csv")

    #data = pd.concat(results)
